# %% [markdown]
# # Environment setup
# Follow the tutorial about how to utilize Google Colab but **don't install PyTorch** as mentioned in the blog post.
#
# Turkish:
# https://medium.com/deep-learning-turkiye/google-colab-ile-%C3%BCcretsiz-gpu-kullan%C4%B1m%C4%B1-30fdb7dd822e
#
# English:
# https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d

# %%
# This part probably will be enough for utilizing Drive in Colab
# but examine links above if you encounter with problems.
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Now, you will work on Architectural Heritage Elements Dataset and classify these elements into 10 categories
#
# After having mounted the Jupyter Notebook to Google Drive, navigate the following address: https://drive.google.com/drive/folders/1PLXZYjGeaM1rekMKUTo8mlaaPeFOrBft?usp=sharing
#
#
# Add this folder entirely to your Google Drive. If you have done it correctly, then you should be able to see *data* folder in your drive.
#
# You can examine the dataset in the following address: https://old.datahub.io/dataset/architectural-heritage-elements-image-dataset

# %% [markdown]
# ### Don't forget to choose the right runtime from the menu above. (GPU should be selected)

# %%
# !nvidia-smi
# This command should return some information about the GPU status if the runtime is right. 
# In addition to that, if you encounter memory issues, you can diagnose your model by this command.
# Out:
# Sun Dec 27 12:42:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### You are free to utilize Pytorch methods in this part of the homework. You will be using pretained models ResNet-50, DenseNet-121 and your own model.

# %%
# All libraries are already presented in Colab Servers, we don't need to install anything with pip
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Pre-trained Models
#
# You can find tutorials on how to load those models at pytorch.org . Don't forget to use pretrained=True if you wish to do finetuning.

# %%
# Reproducible results
torch.manual_seed(2020)
# Load ResNet-50 and DenseNet-121 model seperately here
resnet50 = torch.hub.load('pytorch/vision:v0.6.0', 'resnet50', pretrained=True)
densenet121 = torch.hub.load('pytorch/vision:v0.6.0', 'densenet121', pretrained=True)
# Transfer learning applied below (weights of the models are not updated during training
# except their classifiers)
# Classifiers of both models are replaced with a FC layer with 10 layers at the output
for param in resnet50.parameters():
    param.requires_grad = False
resnet50.fc = nn.Linear(resnet50.fc.in_features, 10)
for param in densenet121.parameters():
    param.requires_grad = False
densenet121.classifier = nn.Linear(densenet121.classifier.in_features, 10)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /root/.cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.6.0
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# HBox(children=(FloatProgress(value=0.0, max=32342954.0), HTML(value='')))

# %% [markdown]
# ## Your Model
#
# Additionally, build your own model which is different from the other models, train on the Architectural Heritage Elements dataset.

# %% [markdown]
# My model defined below can be represented with the following LeNet style NN architectural drawing. It's a very shallow and simple feature extractor.

# %% [markdown]
# ![small_nn.png](data:image/png;base64,...)

# %%
import torch.nn.functional as F


class YourModel(nn.Module):
    def __init__(self):
        # TO DO: Your neural network design
        super(YourModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 3, stride=2, dilation=3, padding=1, padding_mode="reflect")
        self.conv2 = nn.Conv2d(8, 32, 5, stride=5)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 5 * 5, 256)
        self.fc2 = nn.Linear(256, 10)
    def forward(self, x):
        # TO DO: Your neural network design
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
###  Here are some training parameters which you can tweak
batch_size = 64
learning_rate = 1e-3
regularization_rate = 1e-5
n_epochs = 20
use_gpu = True
test_every = 1
momentum = 0.9
###

# You may want to tweak them too and you can use different parameter settings for different models. 
# These are just examples
model = YourModel()
optimizer = optim.SGD(params=model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
criteria = nn.CrossEntropyLoss()

# %% [markdown]
# ## DataLoader
#
# Here we provide you the codes for loading the train data, validation data and test data. Please ensure that you understood how PyTorch methods like ImageFolder, DataLoader and transformations work.

# %%
train_transforms = transforms.Compose([
            transforms.Resize(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
val_transforms = transforms.Compose([
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
test_transforms = transforms.Compose([
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])

abs_path = "/content/drive/MyDrive/ITU - Computer Engineering/BLG561E/HW2"
train_path = os.path.join(abs_path, 'data/train')
val_path = os.path.join(abs_path, 'data/val')
test_path = os.path.join(abs_path, 'data/test')
train_dataset = ImageFolder(train_path, train_transforms)
val_dataset = ImageFolder(val_path, val_transforms)
test_dataset = ImageFolder(test_path, test_transforms)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, num_workers=4, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=32, num_workers=4, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, num_workers=4, shuffle=False)

# %% [markdown]
# # Train your own model
#
# Don't forget to include appropriate regularizations. Choose appropriate set of hyperparameters such as Learning Rate etc. You may insert new cells.

# %%
# It modifies the behaviour of modules like BatchNorm and Dropout for training purposes
# Use your own model
model.train()
if use_gpu:
    model.cuda()
    criteria.cuda()

# Some example diagnostics.

# Loss for every iteration
losses_iter_train = []
# Loss for epoch (averaging the iteration-wise loss)
losses_epoch_train = []
accuracy_iter_train = []
accuracy_epoch_train = []

losses_iter_val = []
losses_epoch_val = []
accuracy_iter_val = []
accuracy_epoch_val = []
running_loss = 0

# Write the training loop
for epoch in range(n_epochs):
    for ix, data in enumerate(train_loader):
        optimizer.zero_grad()
        img, label = data
        if use_gpu:
            img = img.cuda()
            label = label.cuda()
        output = model(img)
        loss = criteria(output, label)
        loss.backward()
        optimizer.step()

        # Statistics
        running_loss += loss.item()
        losses_iter_train.append(loss.item())
        if ix % 40 == 39:    # print every 80 mini-batches
            print('Train [%d, %5d] running loss: %.5f' % (epoch + 1, ix + 1, running_loss/40))
            running_loss = 0
    running_loss = 0
    losses_epoch_train.append(np.mean(losses_iter_train[epoch*len(train_loader):(epoch+1)*len(train_loader)]))
    print('Train [Epoch %d] loss: %.5f' % (epoch + 1, losses_epoch_train[epoch]))

    if epoch % test_every == 0:
        with torch.no_grad():
            model.eval()
            val_ix = epoch // test_every
            total_true = 0
            total_false = 0
            for ix, data in enumerate(val_loader):
                img, label = data
                if use_gpu:
                    img = img.cuda()
                    label = label.cuda()
                output = model(img)
                loss = criteria(output, label)
                _, prediction = torch.max(output.data, 1)
                total_true += torch.sum(prediction == label)
                total_false += torch.sum(prediction != label)
                # Statistics
                running_loss += loss.item()
                losses_iter_val.append(loss.item())
                # pdb.set_trace()
                if ix % 40 == 39:    # print every 40 mini-batches
                    print('Val [%d, %5d] running loss: %.5f' % (epoch + 1, ix + 1, running_loss/40))
                    running_loss = 0
            running_loss = 0
            losses_epoch_val.append(np.mean(losses_iter_val[val_ix*len(val_loader):(val_ix+1)*len(val_loader)]))
            print('Val [Epoch %d] loss: %.5f' % (epoch + 1, losses_epoch_val[val_ix]))
            print('Val Acc: {:.4}%'.format(100 * total_true / (total_true + total_false)))
        model.train()
# Out:
# Train [1,    40] running loss: 2.28606
# Train [1,    80] running loss: 2.21847
# Train [1,   120] running loss: 2.12484
# Train [Epoch 1] loss: 2.18976
# Val [1,    40] running loss: 2.03971
# Val [Epoch 1] loss: 2.05901
# Val Acc: 27.14%
# Train [2,    40] running loss: 1.99343
# Train [2,    80] running loss: 1.90976
# Train [2,   120] running loss: 1.79982
# Train [Epoch 2] loss: 1.87860
# Val [2,    40] running loss: 1.78012
# Val [Epoch 2] loss: 1.80610
# Val Acc: 36.36%
# Train [3,    40] running loss: 1.69482
# Train [3,    80] running loss: 1.66806
# Train [3,   120] running loss: 1.59034
# Train [Epoch 3] loss: 1.64029
# Val [3,    40] running loss: 1.65254
# Val [Epoch 3] loss: 1.65422
# Val Acc: 42.34%
# Train [4,    40] running loss: 1.56514
# Train [4,    80] running loss: 1.51854
# Train [4,   120] running loss: 1.50590
# Train [Epoch 4] loss: 1.52440
# Val [4,    40] running loss: 1.59676
# Val [Epoch 4] loss: 1.59625
# Val Acc: 44.99%
# Train [5,    40] running loss: 1.49216
# Train [5,    80] running loss: 1.42456
# Train [5,   120] running loss: 1.45557
# Train [Epoch 5] loss: 1.45280
# Val [5,    40] running loss: 1.52876
# Val [Epoch 5] loss: 1.53176
# Val Acc: 46.65%
# Train [6,    40] running loss: 1.41214
# Train [6,    80] running loss: 1.38881
# Train [6,   120] running loss: 1.37151
# Train [Epoch 6] loss: 1.39305
# Val [6,    40] running loss: 1.47845
# Val [Epoch 6] loss: 1.49951
# Val Acc: 47.78%
# Train [7,    40] running loss: 1.37232
# Train [7,    80] running loss: 1.33183
# Train [7,   120] running loss: 1.28209
# Train [Epoch 7] loss: 1.32979
# Val [7,    40] running loss: 1.42134
# Val [Epoch 7] loss: 1.42252
# Val Acc: 51.43%
# Train [8,    40] running loss: 1.24030
# Train [8,    80] running loss: 1.29119
# Train [8,   120] running loss: 1.23990
# Train [Epoch 8] loss: 1.25130
# Val [8,    40] running loss: 1.36663
# Val [Epoch 8] loss: 1.35029
# Val Acc: 53.15%
# Train [9,    40] running loss: 1.23102
# Train [9,    80] running loss: 1.19357
# Train [9,   120] running loss: 1.18065
# Train [Epoch 9] loss: 1.18961
# Val [9,    40] running loss: 1.31656
# Val [Epoch 9] loss: 1.32635
# Val Acc: 55.61%
# Train [10,    40] running loss: 1.13616
# Train [10,    80] running loss: 1.15369
# Train [10,   120] running loss: 1.14331
# Train [Epoch 10] loss: 1.14069
# Val [10,    40] running loss: 1.25848
# Val [Epoch 10] loss: 1.26819
# Val Acc: 55.41%
# Train [11,    40] running loss: 1.09236
# Train [11,    80] running loss: 1.13116
# Train [11,   120] running loss: 1.10511
# Train [Epoch 11] loss: 1.10169
# Val [11,    40] running loss: 1.22744
# Val [Epoch 11] loss: 1.23295
# Val Acc: 56.54%
# Train [12,    40] running loss: 1.08523
# Train [12,    80] running loss: 1.04842
# Train [12,   120] running loss: 1.06769
# Train [Epoch 12] loss: 1.06830
# Val [12,    40] running loss: 1.21012
# Val [Epoch 12] loss: 1.19022
# Val Acc: 58.46%
# Train [13,    40] running loss: 1.02426
# Train [13,    80] running loss: 1.06618
# Train [13,   120] running loss: 1.01913
# Train [Epoch 13] loss: 1.03267
# Val [13,    40] running loss: 1.18773
# Val [Epoch 13] loss: 1.17206
# Val Acc: 60.92%
# Train [14,    40] running loss: 1.02015
# Train [14,    80] running loss: 0.99237
# Train [14,   120] running loss: 1.01569
# Train [Epoch 14] loss: 1.00248
# Val [14,    40] running loss: 1.13886
# Val [Epoch 14] loss: 1.13578
# Val Acc: 62.57%
# Train [15,    40] running loss: 0.95522
# Train [15,    80] running loss: 0.98918
# Train [15,   120] running loss: 0.94985
# Train [Epoch 15] loss: 0.96821
# Val [15,    40] running loss: 1.16448
# Val [Epoch 15] loss: 1.16815
# Val Acc: 60.19%
# Train [16,    40] running loss: 0.92715
# Train [16,    80] running loss: 0.96634
# Train [16,   120] running loss: 0.93725
# Train [Epoch 16] loss: 0.94122
# Val [16,    40] running loss: 1.13186
# Val [Epoch 16] loss: 1.12193
# Val Acc: 61.58%
# Train [17,    40] running loss: 0.91839
# Train [17,    80] running loss: 0.92928
# Train [17,   120] running loss: 0.92915
# Train [Epoch 17] loss: 0.92289
# Val [17,    40] running loss: 1.11291
# Val [Epoch 17] loss: 1.10203
# Val Acc: 62.91%
# Train [18,    40] running loss: 0.89119
# Train [18,    80] running loss: 0.90562
# Train [18,   120] running loss: 0.88564
# Train [Epoch 18] loss: 0.89335
# Val [18,    40] running loss: 1.06486
# Val [Epoch 18] loss: 1.06983
# Val Acc: 63.7%
# Train [19,    40] running loss: 0.85197
# Train [19,    80] running loss: 0.87375
# Train [19,   120] running loss: 0.87078
# Train [Epoch 19] loss: 0.86220
# Val [19,    40] running loss: 1.05014
# Val [Epoch 19] loss: 1.04611
# Val Acc: 64.9%
# Train [20,    40] running loss: 0.86683
# Train [20,    80] running loss: 0.84950
# Train [20,   120] running loss: 0.83205
# Train [Epoch 20] loss: 0.84398
# Val [20,    40] running loss: 1.08907
# Val [Epoch 20] loss: 1.06834
# Val Acc: 63.64%

# %% [markdown]
# ## Test your model
#
# Measure the performance against test set. Complete the code below.

# %%
# It modifies the behaviour of modules like BatchNorm and Dropout for test purposes
# Dropout no longer works when .eval() is called.
# BatchNorm uses the learned parameters

model.eval()

with torch.no_grad():
    total_true = 0
    total_false = 0
    for data in test_loader:
        img, label = data
        if use_gpu:
            img = img.cuda()
            label = label.cuda()
        output = model(img)
        _, prediction = torch.max(output.data, 1)
        total_true += torch.sum(prediction == label)
        total_false += torch.sum(prediction != label)
        # Statistics
        # pdb.set_trace()
    print('Test Acc: {:.2f}%'.format(100 * total_true / (total_true + total_false)))

import copy
model_to_save = copy.deepcopy(model)
# Out:
# Test Acc: 59.26%

# %% [markdown]
# # Plot your model

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
axes.plot(losses_epoch_train, c="b", label="Train")
axes.plot(losses_epoch_val, c="r", label="Validation")
axes.set_title("Losses of Your Model")
axes.set_xlabel("Epoch")
axes.set_ylabel("Loss")
axes.legend(loc="best")
fig.tight_layout()

# %% [markdown]
# My model has achieved pretty respectable validation and test accuracies considering how shallow the DNN is. Even though it is not very noticable at the first glance, the model will suffer from overfitting the training data. The momentum of the curves show us that as the number of epochs increase, we will start to see the gap between the validation and the training loss curves get wider.

# %% [markdown]
# # Train, Test and Plot Methods
#
# These methods are defined below in order to reduce code duplication in the upcoming cells.

# %%
def train_model(train_loader, val_loader, model, optimizer, criterion, n_epochs=20, test_every=1, print_every=40):
    model.train()
    if use_gpu:
        model.cuda()
        criteria.cuda()

    losses_iter_train = []
    losses_epoch_train = []

    losses_iter_val = []
    losses_epoch_val = []
    running_loss = 0

    # Write the training loop
    for epoch in range(n_epochs):
        for ix, data in enumerate(train_loader):
            optimizer.zero_grad()
            img, label = data
            if use_gpu:
                img = img.cuda()
                label = label.cuda()
            output = model(img)
            loss = criterion(output, label)
            loss.backward()
            optimizer.step()

            # Statistics
            running_loss += loss.item()
            losses_iter_train.append(loss.item())
            if ix % print_every == print_every - 1:    # print every print_every iteration
                print('Train [%d, %5d] running loss: %.5f' % (epoch + 1, ix + 1, running_loss/print_every))
                running_loss = 0
        running_loss = 0
        losses_epoch_train.append(np.mean(losses_iter_train[epoch*len(train_loader):(epoch+1)*len(train_loader)]))
        print('Train [Epoch %d] loss: %.5f' % (epoch + 1, losses_epoch_train[epoch]))

        if epoch % test_every == 0:
            with torch.no_grad():
                model.eval()
                val_ix = epoch // test_every
                total_true = 0
                total_false = 0
                for ix, data in enumerate(val_loader):
                    img, label = data
                    if use_gpu:
                        img = img.cuda()
                        label = label.cuda()
                    output = model(img)
                    loss = criterion(output, label)
                    _, prediction = torch.max(output.data, 1)
                    total_true += torch.sum(prediction == label)
                    total_false += torch.sum(prediction != label)
                    # Statistics
                    running_loss += loss.item()
                    losses_iter_val.append(loss.item())
                    if ix % print_every == print_every - 1:
                        print('Val [%d, %5d] running loss: %.5f' % (epoch + 1, ix + 1, running_loss/print_every))
                        running_loss = 0
                running_loss = 0
                losses_epoch_val.append(np.mean(losses_iter_val[val_ix*len(val_loader):(val_ix+1)*len(val_loader)]))
                print('Val [Epoch %d] loss: %.5f' % (epoch + 1, losses_epoch_val[val_ix]))
                print('Acc: {:.4}%'.format(100 * total_true / (total_true + total_false)))
            model.train()

    return losses_iter_train, losses_epoch_train, losses_iter_val, losses_epoch_val

# %%
def test_model(test_loader, model):
    model.eval()

    with torch.no_grad():
        total_true = 0
        total_false = 0
        for data in test_loader:
            img, label = data
            if use_gpu:
                img = img.cuda()
                label = label.cuda()
            output = model(img)
            _, prediction = torch.max(output.data, 1)
            total_true += torch.sum(prediction == label)
            total_false += torch.sum(prediction != label)
            # Statistics
        test_acc = 100 * total_true / (total_true + total_false)
        print('Test Acc: {:.2f}%'.format(test_acc))
    
    return test_acc

# %%
def plot_model(train_losses, val_losses, title=None):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
    axes.plot(train_losses, c="b", label="Train")
    axes.plot(val_losses, c="r", label="Validation")
    if title:
        axes.set_title(title)
    else:
        axes.set_title("Epoch Losses")
    axes.set_xlabel("Epoch")
    axes.set_ylabel("Loss")
    axes.legend(loc="best")
    fig.tight_layout()

# %% [markdown]
# # ResNet-50
# ## Train ResNet-50
#
# Avoid overfitting and underfitting as much as possible. **Try to get highest validation and test accuracy (at least 65%)**

# %%
# You can use the same training mechanism above. Now, you will use ResNet-50 as your model
model = resnet50
optimizer = optim.SGD(params=model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
criteria = nn.CrossEntropyLoss()

_, resnet_train_losses, _, resnet_val_losses = train_model(train_loader, val_loader, model, optimizer, criteria, n_epochs=10)
# Out:
# Train [1,    40] running loss: 1.76868
# Train [1,    80] running loss: 0.92061
# Train [1,   120] running loss: 0.64264
# Train [Epoch 1] loss: 1.03932
# Val [1,    40] running loss: 0.50691
# Val [Epoch 1] loss: 0.49535
# Acc: 91.04%
# Train [2,    40] running loss: 0.45814
# Train [2,    80] running loss: 0.41773
# Train [2,   120] running loss: 0.40305
# Train [Epoch 2] loss: 0.42003
# Val [2,    40] running loss: 0.36319
# Val [Epoch 2] loss: 0.34832
# Acc: 91.71%
# Train [3,    40] running loss: 0.35166
# Train [3,    80] running loss: 0.31052
# Train [3,   120] running loss: 0.29235
# Train [Epoch 3] loss: 0.31540
# Val [3,    40] running loss: 0.28385
# Val [Epoch 3] loss: 0.27997
# Acc: 93.3%
# Train [4,    40] running loss: 0.26664
# Train [4,    80] running loss: 0.28206
# Train [4,   120] running loss: 0.25997
# Train [Epoch 4] loss: 0.26918
# Val [4,    40] running loss: 0.25341
# Val [Epoch 4] loss: 0.24494
# Acc: 93.9%
# Train [5,    40] running loss: 0.25526
# Train [5,    80] running loss: 0.23302
# Train [5,   120] running loss: 0.25277
# Train [Epoch 5] loss: 0.24233
# Val [5,    40] running loss: 0.23497
# Val [Epoch 5] loss: 0.22512
# Acc: 93.76%
# Train [6,    40] running loss: 0.22616
# Train [6,    80] running loss: 0.20875
# Train [6,   120] running loss: 0.22633
# Train [Epoch 6] loss: 0.22219
# Val [6,    40] running loss: 0.21818
# Val [Epoch 6] loss: 0.21225
# Acc: 94.16%
# Train [7,    40] running loss: 0.22072
# Train [7,    80] running loss: 0.20220
# Train [7,   120] running loss: 0.20885
# Train [Epoch 7] loss: 0.20777
# Val [7,    40] running loss: 0.20163
# Val [Epoch 7] loss: 0.19965
# Acc: 94.82%
# Train [8,    40] running loss: 0.19188
# Train [8,    80] running loss: 0.19240
# Train [8,   120] running loss: 0.20889
# Train [Epoch 8] loss: 0.19803
# Val [8,    40] running loss: 0.19191
# Val [Epoch 8] loss: 0.18984
# Acc: 94.76%
# Train [9,    40] running loss: 0.19754
# Train [9,    80] running loss: 0.18876
# Train [9,   120] running loss: 0.17834
# Train [Epoch 9] loss: 0.18801
# Val [9,    40] running loss: 0.19013
# Val [Epoch 9] loss: 0.18684
# Acc: 94.69%
# Train [10,    40] running loss: 0.17977
# Train [10,    80] running loss: 0.17619
# Train [10,   120] running loss: 0.19021
# Train [Epoch 10] loss: 0.17945
# Val [10,    40] running loss: 0.18768
# Val [Epoch 10] loss: 0.18183
# Acc: 94.63%

# %% [markdown]
# ## Testing

# %%
# You can use the same testing mechanism above. Now, you will use the ResNet model you trained above
resnet_acc = test_model(test_loader, model)
# Out:
# Test Acc: 70.16%

# %% [markdown]
# ### Plot the training and validation losses versus number of iterations or epochs for ResNet-50 on the same plot and obtain test accuracy

# %%
print('Test Acc: {:.2f}%'.format(resnet_acc))
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
axes.plot(resnet_train_losses, c="b", label="Train")
axes.plot(resnet_val_losses, c="r", label="Validation")
axes.set_title("Epoch Losses")
axes.set_xlabel("Epoch")
axes.set_ylabel("Loss")
axes.legend(loc="best")
fig.tight_layout()
# Out:
# Test Acc: 70.16%

# %% [markdown]
# Pretrained ResNet50 has performed quite well on the validation set, however even though it neither overfit nor underfit the training data, its test set score isn't as remarkable as scores obtained on the validation set.

# %% [markdown]
# # DenseNet-121
# ## Train DenseNet-121
#
# Avoid overfitting and underfitting as much as possible. **Try to get highest validation and test accuracy (at least 65%)**

# %%
# You can use the same training mechanism above. Now, you will use DenseNet-121 as your model 
model = densenet121
optimizer = optim.SGD(params=model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
criteria = nn.CrossEntropyLoss()

_, densenet_train_losses, _, densenet_val_losses = train_model(train_loader, val_loader, model, optimizer, criteria, n_epochs=10)
# Out:
# Train [1,    40] running loss: 1.72580
# Train [1,    80] running loss: 0.92024
# Train [1,   120] running loss: 0.62971
# Train [Epoch 1] loss: 1.02528
# Val [1,    40] running loss: 0.51679
# Val [Epoch 1] loss: 0.50135
# Acc: 87.86%
# Train [2,    40] running loss: 0.47055
# Train [2,    80] running loss: 0.42800
# Train [2,   120] running loss: 0.38159
# Train [Epoch 2] loss: 0.41811
# Val [2,    40] running loss: 0.34977
# Val [Epoch 2] loss: 0.34102
# Acc: 91.9%
# Train [3,    40] running loss: 0.33774
# Train [3,    80] running loss: 0.32437
# Train [3,   120] running loss: 0.29594
# Train [Epoch 3] loss: 0.31672
# Val [3,    40] running loss: 0.29651
# Val [Epoch 3] loss: 0.28510
# Acc: 92.44%
# Train [4,    40] running loss: 0.29628
# Train [4,    80] running loss: 0.27156
# Train [4,   120] running loss: 0.25171
# Train [Epoch 4] loss: 0.26968
# Val [4,    40] running loss: 0.26438
# Val [Epoch 4] loss: 0.25860
# Acc: 92.57%
# Train [5,    40] running loss: 0.26078
# Train [5,    80] running loss: 0.22491
# Train [5,   120] running loss: 0.23837
# Train [Epoch 5] loss: 0.24179
# Val [5,    40] running loss: 0.23180
# Val [Epoch 5] loss: 0.22548
# Acc: 93.83%
# Train [6,    40] running loss: 0.21716
# Train [6,    80] running loss: 0.22677
# Train [6,   120] running loss: 0.21346
# Train [Epoch 6] loss: 0.22078
# Val [6,    40] running loss: 0.22546
# Val [Epoch 6] loss: 0.21551
# Acc: 94.09%
# Train [7,    40] running loss: 0.21478
# Train [7,    80] running loss: 0.18202
# Train [7,   120] running loss: 0.20914
# Train [Epoch 7] loss: 0.20566
# Val [7,    40] running loss: 0.21416
# Val [Epoch 7] loss: 0.20551
# Acc: 93.96%
# Train [8,    40] running loss: 0.19248
# Train [8,    80] running loss: 0.19975
# Train [8,   120] running loss: 0.19634
# Train [Epoch 8] loss: 0.19449
# Val [8,    40] running loss: 0.20664
# Val [Epoch 8] loss: 0.20061
# Acc: 93.7%
# Train [9,    40] running loss: 0.17903
# Train [9,    80] running loss: 0.19268
# Train [9,   120] running loss: 0.18392
# Train [Epoch 9] loss: 0.18557
# Val [9,    40] running loss: 0.20354
# Val [Epoch 9] loss: 0.19356
# Acc: 94.09%
# Train [10,    40] running loss: 0.18456
# Train [10,    80] running loss: 0.17339
# Train [10,   120] running loss: 0.17630
# Train [Epoch 10] loss: 0.17670
# Val [10,    40] running loss: 0.19664
# Val [Epoch 10] loss: 0.18811
# Acc: 94.36%

# %% [markdown]
# ## Testing

# %%
# You can use the same testing mechanism above. Now, you will use the DenseNet model you trained above 
densenet_acc = test_model(test_loader, model)
# Out:
# Test Acc: 86.47%

# %% [markdown]
# ### Plot the training and validation losses versus number of iterations or epochs for DenseNet-121 on the same plot and obtain test accuracy

# %%
print('Test Acc: {:.2f}%'.format(densenet_acc))
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
axes.plot(densenet_train_losses, c="b", label="Train")
axes.plot(densenet_val_losses, c="r", label="Validation")
axes.set_title("Epoch Losses")
axes.set_xlabel("Epoch")
axes.set_ylabel("Loss")
axes.legend(loc="best")
fig.tight_layout()
# Out:
# Test Acc: 86.47%

# %% [markdown]
# Pretrained DenseNet121 has performed quite well both on the validation set and the test set without any signs of over/under-fitting.

# %% [markdown]
# # BatchNorm Comparison
#
# **Create two models one with batchnorm layers and one without batchnorm layers. Train them. If your YourModel() satisfies any of these conditions, you can use it for comparison.**

# %%
# Define your model with BatchNorm and train it. Skip this if you use YourModel() for this condition.
class BatchNormModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 8, 3, stride=2, dilation=3, padding=1, padding_mode="reflect")
        self.conv1_bn = nn.BatchNorm2d(self.conv1.out_channels)
        self.conv2 = nn.Conv2d(8, 32, 5, stride=5)
        self.conv2_bn = nn.BatchNorm2d(self.conv2.out_channels)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 5 * 5, 256)
        self.fc2 = nn.Linear(256, 10)
    def forward(self, x):
        x = self.pool(F.relu(self.conv1_bn(self.conv1(x))))
        x = self.pool(F.relu(self.conv2_bn(self.conv2(x))))
        x = x.view(-1, 32 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


bn_model = BatchNormModel()
bnmodel_optimizer = optim.SGD(bn_model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
_, bnmodel_train_losses, _, bnmodel_val_losses = train_model(train_loader, val_loader, bn_model, bnmodel_optimizer, criteria)
# Out:
# Train [1,    40] running loss: 2.17125
# Train [1,    80] running loss: 1.88081
# Train [1,   120] running loss: 1.71690
# Train [Epoch 1] loss: 1.88464
# Val [1,    40] running loss: 1.68372
# Val [Epoch 1] loss: 1.65162
# Acc: 43.99%
# Train [2,    40] running loss: 1.55885
# Train [2,    80] running loss: 1.45304
# Train [2,   120] running loss: 1.39144
# Train [Epoch 2] loss: 1.45202
# Val [2,    40] running loss: 1.47266
# Val [Epoch 2] loss: 1.44363
# Acc: 49.5%
# Train [3,    40] running loss: 1.31132
# Train [3,    80] running loss: 1.28391
# Train [3,   120] running loss: 1.24846
# Train [Epoch 3] loss: 1.27088
# Val [3,    40] running loss: 1.30170
# Val [Epoch 3] loss: 1.27731
# Acc: 56.93%
# Train [4,    40] running loss: 1.17784
# Train [4,    80] running loss: 1.12486
# Train [4,   120] running loss: 1.07642
# Train [Epoch 4] loss: 1.12260
# Val [4,    40] running loss: 1.15947
# Val [Epoch 4] loss: 1.15722
# Acc: 59.79%
# Train [5,    40] running loss: 1.07615
# Train [5,    80] running loss: 1.03984
# Train [5,   120] running loss: 1.01482
# Train [Epoch 5] loss: 1.04064
# Val [5,    40] running loss: 1.10367
# Val [Epoch 5] loss: 1.07260
# Acc: 62.24%
# Train [6,    40] running loss: 0.98561
# Train [6,    80] running loss: 0.96417
# Train [6,   120] running loss: 0.93847
# Train [Epoch 6] loss: 0.96754
# Val [6,    40] running loss: 1.16433
# Val [Epoch 6] loss: 1.13064
# Acc: 61.98%
# Train [7,    40] running loss: 0.92297
# Train [7,    80] running loss: 0.94065
# Train [7,   120] running loss: 0.93497
# Train [Epoch 7] loss: 0.93694
# Val [7,    40] running loss: 1.03774
# Val [Epoch 7] loss: 1.00242
# Acc: 65.69%
# Train [8,    40] running loss: 0.89727
# Train [8,    80] running loss: 0.91163
# Train [8,   120] running loss: 0.86377
# Train [Epoch 8] loss: 0.89600
# Val [8,    40] running loss: 1.09046
# Val [Epoch 8] loss: 1.04306
# Acc: 65.69%
# Train [9,    40] running loss: 0.89573
# Train [9,    80] running loss: 0.86687
# Train [9,   120] running loss: 0.84489
# Train [Epoch 9] loss: 0.87244
# Val [9,    40] running loss: 0.97791
# Val [Epoch 9] loss: 0.96256
# Acc: 66.89%
# Train [10,    40] running loss: 0.83276
# Train [10,    80] running loss: 0.84341
# Train [10,   120] running loss: 0.80750
# Train [Epoch 10] loss: 0.82970
# Val [10,    40] running loss: 1.00974
# Val [Epoch 10] loss: 0.95280
# Acc: 67.75%
# Train [11,    40] running loss: 0.80864
# Train [11,    80] running loss: 0.80738
# Train [11,   120] running loss: 0.79597
# Train [Epoch 11] loss: 0.80312
# Val [11,    40] running loss: 0.96763
# Val [Epoch 11] loss: 0.93958
# Acc: 68.55%
# Train [12,    40] running loss: 0.77179
# Train [12,    80] running loss: 0.76854
# Train [12,   120] running loss: 0.77102
# Train [Epoch 12] loss: 0.77438
# Val [12,    40] running loss: 0.93356
# Val [Epoch 12] loss: 0.92532
# Acc: 68.75%
# Train [13,    40] running loss: 0.74208
# Train [13,    80] running loss: 0.72602
# Train [13,   120] running loss: 0.77772
# Train [Epoch 13] loss: 0.74829
# Val [13,    40] running loss: 0.90518
# Val [Epoch 13] loss: 0.90561
# Acc: 70.07%
# Train [14,    40] running loss: 0.70910
# Train [14,    80] running loss: 0.72614
# Train [14,   120] running loss: 0.75915
# Train [Epoch 14] loss: 0.72373
# Val [14,    40] running loss: 0.92514
# Val [Epoch 14] loss: 0.88319
# Acc: 70.4%
# Train [15,    40] running loss: 0.71728
# Train [15,    80] running loss: 0.73519
# Train [15,   120] running loss: 0.69169
# Train [Epoch 15] loss: 0.71772
# Val [15,    40] running loss: 0.93333
# Val [Epoch 15] loss: 0.90601
# Acc: 69.28%
# Train [16,    40] running loss: 0.70274
# Train [16,    80] running loss: 0.68510
# Train [16,   120] running loss: 0.69217
# Train [Epoch 16] loss: 0.68523
# Val [16,    40] running loss: 0.96334
# Val [Epoch 16] loss: 0.92921
# Acc: 70.01%
# Train [17,    40] running loss: 0.65175
# Train [17,    80] running loss: 0.69982
# Train [17,   120] running loss: 0.67607
# Train [Epoch 17] loss: 0.67587
# Val [17,    40] running loss: 0.90257
# Val [Epoch 17] loss: 0.87703
# Acc: 70.54%
# Train [18,    40] running loss: 0.66119
# Train [18,    80] running loss: 0.65120
# Train [18,   120] running loss: 0.67709
# Train [Epoch 18] loss: 0.66019
# Val [18,    40] running loss: 0.94264
# Val [Epoch 18] loss: 0.89335
# Acc: 70.74%
# Train [19,    40] running loss: 0.67590
# Train [19,    80] running loss: 0.63241
# Train [19,   120] running loss: 0.63909
# Train [Epoch 19] loss: 0.65495
# Val [19,    40] running loss: 0.85846
# Val [Epoch 19] loss: 0.83951
# Acc: 72.46%
# Train [20,    40] running loss: 0.63433
# Train [20,    80] running loss: 0.63450
# Train [20,   120] running loss: 0.64278
# Train [Epoch 20] loss: 0.63288
# Val [20,    40] running loss: 0.87061
# Val [Epoch 20] loss: 0.84093
# Acc: 72.66%

# %%
# Define your model without BatchNorm and train it. Skip this if you use YourModel() for this condition.
your_model = YourModel()
yourmodel_optimizer = optim.SGD(your_model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
_, yourmodel_train_losses, _, yourmodel_val_losses = train_model(train_loader, val_loader, your_model, yourmodel_optimizer, criteria)
# Out:
# Train [1,    40] running loss: 2.28454
# Train [1,    80] running loss: 2.20417
# Train [1,   120] running loss: 2.15824
# Train [Epoch 1] loss: 2.19990
# Val [1,    40] running loss: 2.12466
# Val [Epoch 1] loss: 2.09508
# Acc: 28.33%
# Train [2,    40] running loss: 2.06023
# Train [2,    80] running loss: 1.91683
# Train [2,   120] running loss: 1.83289
# Train [Epoch 2] loss: 1.92107
# Val [2,    40] running loss: 1.82178
# Val [Epoch 2] loss: 1.81995
# Acc: 37.82%
# Train [3,    40] running loss: 1.78116
# Train [3,    80] running loss: 1.73677
# Train [3,   120] running loss: 1.68770
# Train [Epoch 3] loss: 1.73157
# Val [3,    40] running loss: 1.70981
# Val [Epoch 3] loss: 1.73330
# Acc: 39.28%
# Train [4,    40] running loss: 1.68293
# Train [4,    80] running loss: 1.62392
# Train [4,   120] running loss: 1.57436
# Train [Epoch 4] loss: 1.62094
# Val [4,    40] running loss: 1.62770
# Val [Epoch 4] loss: 1.64280
# Acc: 42.47%
# Train [5,    40] running loss: 1.55246
# Train [5,    80] running loss: 1.50643
# Train [5,   120] running loss: 1.49795
# Train [Epoch 5] loss: 1.51127
# Val [5,    40] running loss: 1.52589
# Val [Epoch 5] loss: 1.53607
# Acc: 47.64%
# Train [6,    40] running loss: 1.42879
# Train [6,    80] running loss: 1.45339
# Train [6,   120] running loss: 1.38351
# Train [Epoch 6] loss: 1.42033
# Val [6,    40] running loss: 1.52371
# Val [Epoch 6] loss: 1.51135
# Acc: 47.25%
# Train [7,    40] running loss: 1.40024
# Train [7,    80] running loss: 1.34081
# Train [7,   120] running loss: 1.30075
# Train [Epoch 7] loss: 1.34714
# Val [7,    40] running loss: 1.40283
# Val [Epoch 7] loss: 1.46278
# Acc: 51.03%
# Train [8,    40] running loss: 1.30640
# Train [8,    80] running loss: 1.24385
# Train [8,   120] running loss: 1.28963
# Train [Epoch 8] loss: 1.27138
# Val [8,    40] running loss: 1.38377
# Val [Epoch 8] loss: 1.40392
# Acc: 52.55%
# Train [9,    40] running loss: 1.23215
# Train [9,    80] running loss: 1.21736
# Train [9,   120] running loss: 1.19917
# Train [Epoch 9] loss: 1.21020
# Val [9,    40] running loss: 1.31179
# Val [Epoch 9] loss: 1.32921
# Acc: 55.08%
# Train [10,    40] running loss: 1.15624
# Train [10,    80] running loss: 1.13662
# Train [10,   120] running loss: 1.13053
# Train [Epoch 10] loss: 1.14327
# Val [10,    40] running loss: 1.26719
# Val [Epoch 10] loss: 1.27657
# Acc: 56.07%
# Train [11,    40] running loss: 1.06238
# Train [11,    80] running loss: 1.08676
# Train [11,   120] running loss: 1.10449
# Train [Epoch 11] loss: 1.08383
# Val [11,    40] running loss: 1.24226
# Val [Epoch 11] loss: 1.21367
# Acc: 58.39%
# Train [12,    40] running loss: 1.06384
# Train [12,    80] running loss: 1.07841
# Train [12,   120] running loss: 1.04780
# Train [Epoch 12] loss: 1.05340
# Val [12,    40] running loss: 1.19123
# Val [Epoch 12] loss: 1.19751
# Acc: 58.39%
# Train [13,    40] running loss: 1.02027
# Train [13,    80] running loss: 1.06198
# Train [13,   120] running loss: 1.00265
# Train [Epoch 13] loss: 1.02192
# Val [13,    40] running loss: 1.14188
# Val [Epoch 13] loss: 1.20477
# Acc: 59.92%
# Train [14,    40] running loss: 1.01741
# Train [14,    80] running loss: 0.97344
# Train [14,   120] running loss: 0.98846
# Train [Epoch 14] loss: 0.98721
# Val [14,    40] running loss: 1.11918
# Val [Epoch 14] loss: 1.15218
# Acc: 59.99%
# Train [15,    40] running loss: 0.95240
# Train [15,    80] running loss: 0.94199
# Train [15,   120] running loss: 0.91197
# Train [Epoch 15] loss: 0.94291
# Val [15,    40] running loss: 1.06914
# Val [Epoch 15] loss: 1.11691
# Acc: 62.64%
# Train [16,    40] running loss: 0.94165
# Train [16,    80] running loss: 0.90584
# Train [16,   120] running loss: 0.90632
# Train [Epoch 16] loss: 0.92460
# Val [16,    40] running loss: 1.10216
# Val [Epoch 16] loss: 1.10255
# Acc: 62.71%
# Train [17,    40] running loss: 0.90992
# Train [17,    80] running loss: 0.90651
# Train [17,   120] running loss: 0.90734
# Train [Epoch 17] loss: 0.90315
# Val [17,    40] running loss: 1.09451
# Val [Epoch 17] loss: 1.09440
# Acc: 62.91%
# Train [18,    40] running loss: 0.88238
# Train [18,    80] running loss: 0.87015
# Train [18,   120] running loss: 0.87347
# Train [Epoch 18] loss: 0.87554
# Val [18,    40] running loss: 1.08173
# Val [Epoch 18] loss: 1.08967
# Acc: 63.44%
# Train [19,    40] running loss: 0.82946
# Train [19,    80] running loss: 0.84805
# Train [19,   120] running loss: 0.88697
# Train [Epoch 19] loss: 0.85620
# Val [19,    40] running loss: 1.03955
# Val [Epoch 19] loss: 1.05473
# Acc: 63.84%
# Train [20,    40] running loss: 0.86981
# Train [20,    80] running loss: 0.83310
# Train [20,   120] running loss: 0.82036
# Train [Epoch 20] loss: 0.84261
# Val [20,    40] running loss: 1.02871
# Val [Epoch 20] loss: 1.07307
# Acc: 63.37%

# %% [markdown]
# **For each, plot the training and validation losses versus number of iterations or epochs and compare test accuracies.**

# %%
yourmodel_acc = test_model(test_loader, your_model)
plot_model(yourmodel_train_losses, yourmodel_val_losses, "Your Model Losses Plot")
# Out:
# Test Acc: 55.77%

# %%
bnmodel_acc = test_model(test_loader, bn_model)
plot_model(bnmodel_train_losses, bnmodel_val_losses, "BatchNorm Model Losses Plot")
# Out:
# Test Acc: 57.98%

# %% [markdown]
# Batch normalization helped generalize the data better, increased the accuracy and the stability of our network as expected. By normalizing the intermediary values, it allowed our network layers to learn independently from one another. Please note that the test accuracy of YourModel() differs from the initial one because weights are randomly initialized each run and YourModel() is trained from scratch TWICE. This is intentional in order to show the results in a more compact fashion.

# %% [markdown]
# # Dropout Comparison
#
# **Create two models one with dropout layers and one without dropout layers. Train them. If your YourModel() satisfies any of these conditions, you can use it for comparison.**

# %%
# Define your model with Dropout and train it. Skip this if you use YourModel() for this condition.
class DropoutModel(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 8, 3, stride=2, dilation=3, padding=1, padding_mode="reflect")
        self.conv2 = nn.Conv2d(8, 32, 5, stride=5)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 5 * 5, 256)
        self.fc2 = nn.Linear(256, 10)
        self.dropout = nn.Dropout(p)
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 5 * 5)
        x = F.relu(self.dropout(self.fc1(x)))
        x = self.dropout(self.fc2(x))
        return x


dropout_model = DropoutModel(p=0.2)
dropoutmodel_optimizer = optim.SGD(dropout_model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=regularization_rate)
_, dropoutmodel_train_losses, _, dropoutmodel_val_losses = train_model(train_loader, val_loader, dropout_model, dropoutmodel_optimizer, criteria)
# Out:
# Train [1,    40] running loss: 2.27257
# Train [1,    80] running loss: 2.20701
# Train [1,   120] running loss: 2.13349
# Train [Epoch 1] loss: 2.18801
# Val [1,    40] running loss: 2.02889
# Val [Epoch 1] loss: 2.03487
# Acc: 29.0%
# Train [2,    40] running loss: 2.00113
# Train [2,    80] running loss: 1.92473
# Train [2,   120] running loss: 1.91799
# Train [Epoch 2] loss: 1.94075
# Val [2,    40] running loss: 1.83070
# Val [Epoch 2] loss: 1.83040
# Acc: 37.76%
# Train [3,    40] running loss: 1.86437
# Train [3,    80] running loss: 1.80157
# Train [3,   120] running loss: 1.80657
# Train [Epoch 3] loss: 1.81989
# Val [3,    40] running loss: 1.70727
# Val [Epoch 3] loss: 1.72005
# Acc: 41.94%
# Train [4,    40] running loss: 1.74309
# Train [4,    80] running loss: 1.69613
# Train [4,   120] running loss: 1.70875
# Train [Epoch 4] loss: 1.71462
# Val [4,    40] running loss: 1.64855
# Val [Epoch 4] loss: 1.62194
# Acc: 44.72%
# Train [5,    40] running loss: 1.65689
# Train [5,    80] running loss: 1.65644
# Train [5,   120] running loss: 1.62248
# Train [Epoch 5] loss: 1.64718
# Val [5,    40] running loss: 1.57916
# Val [Epoch 5] loss: 1.57478
# Acc: 45.12%
# Train [6,    40] running loss: 1.62716
# Train [6,    80] running loss: 1.62936
# Train [6,   120] running loss: 1.57906
# Train [Epoch 6] loss: 1.60804
# Val [6,    40] running loss: 1.52830
# Val [Epoch 6] loss: 1.52019
# Acc: 46.91%
# Train [7,    40] running loss: 1.58386
# Train [7,    80] running loss: 1.56992
# Train [7,   120] running loss: 1.55502
# Train [Epoch 7] loss: 1.55808
# Val [7,    40] running loss: 1.46005
# Val [Epoch 7] loss: 1.46502
# Acc: 49.64%
# Train [8,    40] running loss: 1.53359
# Train [8,    80] running loss: 1.54203
# Train [8,   120] running loss: 1.46998
# Train [Epoch 8] loss: 1.51275
# Val [8,    40] running loss: 1.43758
# Val [Epoch 8] loss: 1.43172
# Acc: 50.43%
# Train [9,    40] running loss: 1.49833
# Train [9,    80] running loss: 1.48997
# Train [9,   120] running loss: 1.43942
# Train [Epoch 9] loss: 1.48318
# Val [9,    40] running loss: 1.39993
# Val [Epoch 9] loss: 1.40888
# Acc: 51.69%
# Train [10,    40] running loss: 1.46342
# Train [10,    80] running loss: 1.42171
# Train [10,   120] running loss: 1.42484
# Train [Epoch 10] loss: 1.43666
# Val [10,    40] running loss: 1.38156
# Val [Epoch 10] loss: 1.36626
# Acc: 54.08%
# Train [11,    40] running loss: 1.41187
# Train [11,    80] running loss: 1.35959
# Train [11,   120] running loss: 1.42182
# Train [Epoch 11] loss: 1.39540
# Val [11,    40] running loss: 1.33447
# Val [Epoch 11] loss: 1.31044
# Acc: 54.88%
# Train [12,    40] running loss: 1.35561
# Train [12,    80] running loss: 1.41518
# Train [12,   120] running loss: 1.37697
# Train [Epoch 12] loss: 1.38061
# Val [12,    40] running loss: 1.25564
# Val [Epoch 12] loss: 1.29525
# Acc: 54.68%
# Train [13,    40] running loss: 1.35441
# Train [13,    80] running loss: 1.33724
# Train [13,   120] running loss: 1.31649
# Train [Epoch 13] loss: 1.34273
# Val [13,    40] running loss: 1.26221
# Val [Epoch 13] loss: 1.24660
# Acc: 56.67%
# Train [14,    40] running loss: 1.30230
# Train [14,    80] running loss: 1.28671
# Train [14,   120] running loss: 1.30947
# Train [Epoch 14] loss: 1.30324
# Val [14,    40] running loss: 1.18873
# Val [Epoch 14] loss: 1.20783
# Acc: 59.06%
# Train [15,    40] running loss: 1.27016
# Train [15,    80] running loss: 1.26386
# Train [15,   120] running loss: 1.25762
# Train [Epoch 15] loss: 1.25724
# Val [15,    40] running loss: 1.15069
# Val [Epoch 15] loss: 1.17999
# Acc: 59.59%
# Train [16,    40] running loss: 1.23757
# Train [16,    80] running loss: 1.25430
# Train [16,   120] running loss: 1.21473
# Train [Epoch 16] loss: 1.23652
# Val [16,    40] running loss: 1.14782
# Val [Epoch 16] loss: 1.13383
# Acc: 61.58%
# Train [17,    40] running loss: 1.19955
# Train [17,    80] running loss: 1.24208
# Train [17,   120] running loss: 1.17230
# Train [Epoch 17] loss: 1.20476
# Val [17,    40] running loss: 1.11665
# Val [Epoch 17] loss: 1.11011
# Acc: 61.51%
# Train [18,    40] running loss: 1.21355
# Train [18,    80] running loss: 1.16307
# Train [18,   120] running loss: 1.16265
# Train [Epoch 18] loss: 1.18674
# Val [18,    40] running loss: 1.08780
# Val [Epoch 18] loss: 1.13303
# Acc: 61.11%
# Train [19,    40] running loss: 1.14614
# Train [19,    80] running loss: 1.16163
# Train [19,   120] running loss: 1.15163
# Train [Epoch 19] loss: 1.15275
# Val [19,    40] running loss: 1.04461
# Val [Epoch 19] loss: 1.06027
# Acc: 64.83%
# Train [20,    40] running loss: 1.15036
# Train [20,    80] running loss: 1.09661
# Train [20,   120] running loss: 1.12741
# Train [Epoch 20] loss: 1.12293
# Val [20,    40] running loss: 1.04918
# Val [Epoch 20] loss: 1.03869
# Acc: 64.57%

# %%
# Define your model without Dropout and train it. Skip this if you use YourModel() for this condition.

# %% [markdown]
# **For each, plot the training and validation losses versus number of iterations or epochs and compare test accuracies.**

# %%
yourmodel_acc = test_model(test_loader, your_model)
plot_model(yourmodel_train_losses, yourmodel_val_losses, "Your Model Losses Plot")
# Out:
# Test Acc: 55.77%

# %%
dropoutmodel_acc = test_model(test_loader, dropout_model)
plot_model(dropoutmodel_train_losses, dropoutmodel_val_losses, "Dropout Model Losses Plot where $p=0.2$")
# Out:
# Test Acc: 57.83%

# %% [markdown]
# A similar conclusion can be made for the dropout as well. By randomly choosing which neurons to activate at each run, our model generalized to the data better and achieved higher accuracy results. It should also be noted that $p$ is not the probability to keep to neurons as implemented in the homework. In PyTorch, $p$ is the probability to zero out a random neuron.

# %% [markdown]
# # Optimizer Comparison
#
# **Optimize two identical models one with SGD+Momentum and one with Adam. If your training for YourModel() satisfies any of these conditions, you can use it for comparison.**

# %%
# Train your model with SGD+Momentum. Skip this if you use YourModel() for this condition.

# %%
# Train your model with Adam. Skip this if you use YourModel() for this condition.
adam_model = YourModel()
adam_optimizer = optim.Adam(adam_model.parameters(), lr=learning_rate, weight_decay=regularization_rate)
_, adam_train_losses, _, adam_val_losses = train_model(train_loader, val_loader, adam_model, adam_optimizer, criteria)
# Out:
# Train [1,    40] running loss: 1.92992
# Train [1,    80] running loss: 1.54143
# Train [1,   120] running loss: 1.34074
# Train [Epoch 1] loss: 1.55730
# Val [1,    40] running loss: 1.39325
# Val [Epoch 1] loss: 1.40337
# Acc: 51.16%
# Train [2,    40] running loss: 1.17799
# Train [2,    80] running loss: 1.12448
# Train [2,   120] running loss: 1.07885
# Train [Epoch 2] loss: 1.11447
# Val [2,    40] running loss: 1.10694
# Val [Epoch 2] loss: 1.14104
# Acc: 60.45%
# Train [3,    40] running loss: 1.01225
# Train [3,    80] running loss: 0.97355
# Train [3,   120] running loss: 0.96825
# Train [Epoch 3] loss: 0.98041
# Val [3,    40] running loss: 1.06369
# Val [Epoch 3] loss: 1.10352
# Acc: 62.18%
# Train [4,    40] running loss: 0.87406
# Train [4,    80] running loss: 0.87949
# Train [4,   120] running loss: 0.91074
# Train [Epoch 4] loss: 0.89162
# Val [4,    40] running loss: 1.02286
# Val [Epoch 4] loss: 1.03848
# Acc: 64.96%
# Train [5,    40] running loss: 0.79786
# Train [5,    80] running loss: 0.84492
# Train [5,   120] running loss: 0.79541
# Train [Epoch 5] loss: 0.81849
# Val [5,    40] running loss: 0.97954
# Val [Epoch 5] loss: 1.04159
# Acc: 64.96%
# Train [6,    40] running loss: 0.73776
# Train [6,    80] running loss: 0.78457
# Train [6,   120] running loss: 0.76948
# Train [Epoch 6] loss: 0.75888
# Val [6,    40] running loss: 1.02216
# Val [Epoch 6] loss: 1.03824
# Acc: 66.36%
# Train [7,    40] running loss: 0.70845
# Train [7,    80] running loss: 0.67748
# Train [7,   120] running loss: 0.70649
# Train [Epoch 7] loss: 0.69803
# Val [7,    40] running loss: 0.90943
# Val [Epoch 7] loss: 0.97526
# Acc: 67.55%
# Train [8,    40] running loss: 0.64903
# Train [8,    80] running loss: 0.65655
# Train [8,   120] running loss: 0.67694
# Train [Epoch 8] loss: 0.66234
# Val [8,    40] running loss: 0.91305
# Val [Epoch 8] loss: 0.93474
# Acc: 68.94%
# Train [9,    40] running loss: 0.59994
# Train [9,    80] running loss: 0.58884
# Train [9,   120] running loss: 0.60203
# Train [Epoch 9] loss: 0.60114
# Val [9,    40] running loss: 0.92430
# Val [Epoch 9] loss: 0.93459
# Acc: 69.01%
# Train [10,    40] running loss: 0.56352
# Train [10,    80] running loss: 0.57181
# Train [10,   120] running loss: 0.56271
# Train [Epoch 10] loss: 0.56409
# Val [10,    40] running loss: 0.96199
# Val [Epoch 10] loss: 0.96246
# Acc: 70.01%
# Train [11,    40] running loss: 0.54578
# Train [11,    80] running loss: 0.52168
# Train [11,   120] running loss: 0.54386
# Train [Epoch 11] loss: 0.53701
# Val [11,    40] running loss: 0.96099
# Val [Epoch 11] loss: 0.97287
# Acc: 68.75%
# Train [12,    40] running loss: 0.49502
# Train [12,    80] running loss: 0.47313
# Train [12,   120] running loss: 0.49204
# Train [Epoch 12] loss: 0.49550
# Val [12,    40] running loss: 0.91809
# Val [Epoch 12] loss: 0.90493
# Acc: 71.07%
# Train [13,    40] running loss: 0.45586
# Train [13,    80] running loss: 0.40298
# Train [13,   120] running loss: 0.47548
# Train [Epoch 13] loss: 0.44446
# Val [13,    40] running loss: 1.04152
# Val [Epoch 13] loss: 1.00596
# Acc: 69.01%
# Train [14,    40] running loss: 0.40837
# Train [14,    80] running loss: 0.41431
# Train [14,   120] running loss: 0.41410
# Train [Epoch 14] loss: 0.40881
# Val [14,    40] running loss: 0.97450
# Val [Epoch 14] loss: 0.97459
# Acc: 71.47%
# Train [15,    40] running loss: 0.33288
# Train [15,    80] running loss: 0.37450
# Train [15,   120] running loss: 0.36791
# Train [Epoch 15] loss: 0.35626
# Val [15,    40] running loss: 1.00761
# Val [Epoch 15] loss: 1.01350
# Acc: 71.27%
# Train [16,    40] running loss: 0.33015
# Train [16,    80] running loss: 0.35620
# Train [16,   120] running loss: 0.38835
# Train [Epoch 16] loss: 0.35820
# Val [16,    40] running loss: 1.00282
# Val [Epoch 16] loss: 1.03382
# Acc: 70.27%
# Train [17,    40] running loss: 0.29914
# Train [17,    80] running loss: 0.29596
# Train [17,   120] running loss: 0.31612
# Train [Epoch 17] loss: 0.30542
# Val [17,    40] running loss: 1.08987
# Val [Epoch 17] loss: 1.09804
# Acc: 69.08%
# Train [18,    40] running loss: 0.27607
# Train [18,    80] running loss: 0.28640
# Train [18,   120] running loss: 0.26807
# Train [Epoch 18] loss: 0.28110
# Val [18,    40] running loss: 1.09276
# Val [Epoch 18] loss: 1.11803
# Acc: 70.54%
# Train [19,    40] running loss: 0.25406
# Train [19,    80] running loss: 0.23491
# Train [19,   120] running loss: 0.23949
# Train [Epoch 19] loss: 0.24311
# Val [19,    40] running loss: 1.02817
# Val [Epoch 19] loss: 1.06452
# Acc: 71.86%
# Train [20,    40] running loss: 0.21782
# Train [20,    80] running loss: 0.21044
# Train [20,   120] running loss: 0.21570
# Train [Epoch 20] loss: 0.21535
# Val [20,    40] running loss: 1.14945
# Val [Epoch 20] loss: 1.18672
# Acc: 70.74%

# %% [markdown]
# **For each, plot the training and validation losses versus number of iterations or epochs and compare test accuracies**

# %%
sgd_acc = test_model(test_loader, your_model)
plot_model(yourmodel_train_losses, yourmodel_val_losses, "SGD Optimized Your Model Losses Plot")
# Out:
# Test Acc: 55.77%

# %%
adam_acc = test_model(test_loader, adam_model)
plot_model(adam_train_losses, adam_val_losses, "Adam Optimized Your Model Losses Plot")
# Out:
# Test Acc: 58.83%

# %% [markdown]
# Adam optimizer has helped the model to learn and fit to the data a lot faster than SGD, by taking optimization steps resulted from computation of the decaying average of past squared gradients (RMSProp alike) and past gradients (SGD with momentum alike). Thanks to this, we can now observe within 10 to 12 epochs that our model is not sufficient enough to generalize and needs to be deeper. By increasing the number of convolutions and kernels, we can allow our model to learn more features.

# %% [markdown]
# #### After you have completed the training, save your best model using the following command
# #### Upload your best model to Google Drive and copy your link here: [Link to Model](https://drive.google.com/file/d/1KeUnEBfPK2QBzhlc-F6iTkf_YD3RIcar/view?usp=sharing) (https://drive.google.com/file/d/1KeUnEBfPK2QBzhlc-F6iTkf_YD3RIcar/view?usp=sharing)

# %%
student_id = 150180705
model_path = os.path.join(abs_path, '{}.pth'.format(student_id))
torch.save(model_to_save.state_dict(), model_path)
